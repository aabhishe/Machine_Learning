# %% [markdown]
# ## Machine Learning code to calculate screen time of different movie characters from a video using VGG16 model

# %% [markdown]
# ## *Import Libraries*
# ### We will need following libraries
#     ### - OpenCV
#     ### - Keras
#     ### - Pandas
#     ### - Numpy
#     ### - Matplotlib
#     ### - Skimage
#     ### - Math
#     ### - sklearn

# %%
import cv2
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.preprocessing import image
from keras.utils import np_utils
from keras.applications.vgg16 import preprocess_input
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, InputLayer, Dropout

# %% [markdown]
# ### Read the video file
# ### Find out the fps of the video and capture frames from video at that fps and then save those images

# %%
#Set file name
VDO_FL_Name = "Tom and jerry.mp4"
#capture the file
Tom_and_Jerry_VDO_FL = cv2.VideoCapture(VDO_FL_Name)
#get the fps
FrameRate= Tom_and_Jerry_VDO_FL.get(cv2.CAP_PROP_FPS)
print("video fps",framerate)
count =0
x=1
while(Tom_and_Jerry_VDO_FL.isOpened()):
    FrameID=Tom_and_Jerry_VDO_FL.get(cv2.CAP_PROP_POS_FRAMES)
    #read the next frame
    ret,frame = Tom_and_Jerry_VDO_FL.read()
    #break at end of the file
    if(ret != True):
            break
    #save the frame as iamge file
    if(FrameID % math.floor(FrameRate) == 0):
            #save the image as frame number jpg file
            filename = "frame%d.jpg"%count;count+=1
            cv2.imwrite(filename,frame)
#close the file
Tom_and_Jerry_VDO_FL.release()
print("total number of images saved",count)
# Out:
# video fps 8912.0
# total number of frames saved 298

# %% [markdown]
# ### load the labeled file to map each training set into three classes -
#     - Neither Tom nor Jerry - Class 0
#     - Jerry - Class 1
#     - Tom - Class 2
# ### map the training set with their corresponding class

# %%
# read the mapping label data
mapping = pd.read_csv("mapping.csv")
mapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 2 columns):
# Image_ID    298 non-null object
# Class       298 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 4.7+ KB

# %%
mapping.head(12)
# Out:
#        Image_ID  Class
# 0    frame0.jpg      1
# 1    frame1.jpg      1
# 2    frame2.jpg      2
# 3    frame3.jpg      2
# 4    frame4.jpg      2
# 5    frame5.jpg      2
# 6    frame6.jpg      2
# 7    frame7.jpg      2
# 8    frame8.jpg      2
# 9    frame9.jpg      2
# 10  frame10.jpg      2
# 11  frame11.jpg      0

# %%
#store images in an array
images =[]
for img_name in mapping.Image_ID:
    img=plt.imread(''+img_name)
    images.append(img)
images = np.array(images)
print("image size is:", images.shape)
#check the 1st image
plt.imshow(images[0])
# Out:
# image size is: (298, 720, 1280, 3)

# %%
plt.imshow(images[2])

# %%
plt.imshow(images[11])

# %%
# convert image classes into categorial variables
img_calss = mapping.Class
dummy_img_class = np_utils.to_categorical(img_calss)
dummy_img_class.shape
# Out:
# (298, 3)

# %% [markdown]
# ### reshaping images to 224x224x3 to use models like VGG16

# %%
img=[]
for i in range(0,images.shape[0]):
    a = resize(images[i],preserve_range=True,output_shape=(224,224)).astype(int)
    img.append(a)
images=np.array(img)
print("updated iamge size is:",images.shape)
#check the 1st image
plt.imshow(images[0])
# Out:
# C:\Users\alok_\Anaconda\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\alok_\Anaconda\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# updated iamge size is: (298, 224, 224, 3)

# %%
#preprocess image for VGG16
image_pp_vgg16 = preprocess_input(images,mode='tf')

# %%
#create training set and testing set
img_train,img_test,class_train,class_test = train_test_split(image_pp_vgg16,dummy_img_class,test_size=0.3,random_state=42)
print("training set count:",img_train.shape[0])
print("testing set count:",img_test.shape[0])
# Out:
# training set count: 208
# testing set count: 90

# %% [markdown]
# ### Build the model

# %%
vgg16_base_model = VGG16(weights='imagenet',include_top=False,input_shape=(224,224,3))
img_train=vgg16_base_model.predict(img_train)
img_test = vgg16_base_model.predict(img_test)
print(img_train.shape)
print(img_test.shape)
img_train = img_train.reshape(208,7*7*512)
img_test = img_test.reshape(90,7*7*512)
print(img_train.shape)
print(img_test.shape)
# Out:
# (208, 7, 7, 512)
# (90, 7, 7, 512)
# (208, 25088)
# (90, 25088)

# %%
train = img_train/img_train.max()
test = img_test/img_test.max()

# %%
model = Sequential()
model.add(InputLayer((7*7*512,)))
model.add(Dense(units=1024,activation='sigmoid'))
model.add(Dense(3,activation='softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 1024)              25691136
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 25,694,211
# Trainable params: 25,694,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_perf_sig = model.fit(train,class_train,epochs=50,validation_data=(test,class_test))
# Out:
# Train on 208 samples, validate on 90 samples
# Epoch 1/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0149 - acc: 0.9952 - val_loss: 0.3470 - val_acc: 0.8556
# Epoch 2/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0109 - acc: 0.9952 - val_loss: 0.3932 - val_acc: 0.8556
# Epoch 3/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0154 - acc: 0.9952 - val_loss: 0.3893 - val_acc: 0.8556
# Epoch 4/50
# 208/208 [==============================] - 3s 17ms/step - loss: 0.0224 - acc: 0.9904 - val_loss: 0.3030 - val_acc: 0.8778
# Epoch 5/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0130 - acc: 0.9952 - val_loss: 0.3896 - val_acc: 0.8556
# Epoch 6/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0159 - acc: 0.9952 - val_loss: 0.4208 - val_acc: 0.8556
# Epoch 7/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0096 - acc: 0.9952 - val_loss: 0.3158 - val_acc: 0.8667
# Epoch 8/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0170 - acc: 0.9952 - val_loss: 0.3211 - val_acc: 0.8667
# Epoch 9/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0098 - acc: 0.9952 - val_loss: 0.5450 - val_acc: 0.8333
# Epoch 10/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0220 - acc: 0.9952 - val_loss: 0.3906 - val_acc: 0.8667
# Epoch 11/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0102 - acc: 0.9952 - val_loss: 0.3126 - val_acc: 0.8667
# Epoch 12/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0162 - acc: 0.9952 - val_loss: 0.3318 - val_acc: 0.8444
# Epoch 13/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0104 - acc: 0.9952 - val_loss: 0.3959 - val_acc: 0.8556
# Epoch 14/50
# 208/208 [==============================] - 3s 17ms/step - loss: 0.0167 - acc: 0.9904 - val_loss: 0.3367 - val_acc: 0.8556
# Epoch 15/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0127 - acc: 0.9904 - val_loss: 0.4135 - val_acc: 0.8556
# Epoch 16/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0158 - acc: 0.9904 - val_loss: 0.3548 - val_acc: 0.8556
# Epoch 17/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0087 - acc: 0.9952 - val_loss: 0.5024 - val_acc: 0.8333
# Epoch 18/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0211 - acc: 0.9952 - val_loss: 0.3581 - val_acc: 0.8556
# Epoch 19/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0190 - acc: 0.9904 - val_loss: 0.3148 - val_acc: 0.8667
# Epoch 20/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0106 - acc: 0.9952 - val_loss: 0.3775 - val_acc: 0.8556
# Epoch 21/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0087 - acc: 0.9952 - val_loss: 0.3823 - val_acc: 0.8556
# Epoch 22/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0111 - acc: 0.9952 - val_loss: 0.3746 - val_acc: 0.8556
# Epoch 23/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0196 - acc: 0.9952 - val_loss: 0.4976 - val_acc: 0.8333
# Epoch 24/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0175 - acc: 0.9904 - val_loss: 0.3347 - val_acc: 0.8556
# Epoch 25/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0074 - acc: 0.9952 - val_loss: 0.3615 - val_acc: 0.8556
# Epoch 26/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0136 - acc: 0.9952 - val_loss: 0.3719 - val_acc: 0.8556
# Epoch 27/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0099 - acc: 0.9952 - val_loss: 0.3123 - val_acc: 0.9000
# Epoch 28/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0153 - acc: 0.9952 - val_loss: 0.3631 - val_acc: 0.8556
# Epoch 29/50
# 208/208 [==============================] - 3s 17ms/step - loss: 0.0094 - acc: 0.9904 - val_loss: 0.4138 - val_acc: 0.8556
# Epoch 30/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0107 - acc: 0.9904 - val_loss: 0.3755 - val_acc: 0.8556
# Epoch 31/50
# 208/208 [==============================] - 5s 22ms/step - loss: 0.0106 - acc: 0.9952 - val_loss: 0.3798 - val_acc: 0.8556
# Epoch 32/50
# 208/208 [==============================] - 6s 29ms/step - loss: 0.0078 - acc: 0.9952 - val_loss: 0.4099 - val_acc: 0.8556
# Epoch 33/50
# 208/208 [==============================] - 6s 29ms/step - loss: 0.0136 - acc: 0.9904 - val_loss: 0.3521 - val_acc: 0.8556
# Epoch 34/50
# 208/208 [==============================] - 6s 27ms/step - loss: 0.0094 - acc: 0.9904 - val_loss: 0.3926 - val_acc: 0.8667
# Epoch 35/50
# 208/208 [==============================] - 4s 22ms/step - loss: 0.0134 - acc: 0.9952 - val_loss: 0.3913 - val_acc: 0.8556
# Epoch 36/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0080 - acc: 0.9952 - val_loss: 0.3151 - val_acc: 0.8778
# Epoch 37/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0166 - acc: 0.9952 - val_loss: 0.3557 - val_acc: 0.8556
# Epoch 38/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0089 - acc: 0.9952 - val_loss: 0.4017 - val_acc: 0.8556
# Epoch 39/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0138 - acc: 0.9952 - val_loss: 0.4311 - val_acc: 0.8556
# Epoch 40/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0220 - acc: 0.9952 - val_loss: 0.3152 - val_acc: 0.9000
# Epoch 41/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0197 - acc: 0.9952 - val_loss: 0.3973 - val_acc: 0.8556
# Epoch 42/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0161 - acc: 0.9952 - val_loss: 0.4942 - val_acc: 0.8444
# Epoch 43/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0187 - acc: 0.9904 - val_loss: 0.3389 - val_acc: 0.8556
# Epoch 44/50
# 208/208 [==============================] - 5s 25ms/step - loss: 0.0117 - acc: 0.9952 - val_loss: 0.4006 - val_acc: 0.8556
# Epoch 45/50
# 208/208 [==============================] - 5s 25ms/step - loss: 0.0098 - acc: 0.9952 - val_loss: 0.3779 - val_acc: 0.8556
# Epoch 46/50
# 208/208 [==============================] - 5s 22ms/step - loss: 0.0078 - acc: 0.9952 - val_loss: 0.3356 - val_acc: 0.8556
# Epoch 47/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0105 - acc: 0.9952 - val_loss: 0.3586 - val_acc: 0.8556
# Epoch 48/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0108 - acc: 0.9952 - val_loss: 0.3602 - val_acc: 0.8556
# Epoch 49/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0203 - acc: 0.9904 - val_loss: 0.4749 - val_acc: 0.8556
# Epoch 50/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0233 - acc: 0.9904 - val_loss: 0.3202 - val_acc: 0.9000

# %%
print(model_perf_sig.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.plot(model_perf_sig.history['acc'])
plt.plot(model_perf_sig.history['val_acc'])
plt.title('model accuracy - sigmoid')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='mideel left')
plt.show()
# Out:
# C:\Users\alok_\Anaconda\lib\site-packages\matplotlib\legend.py:641: UserWarning: Unrecognized location "mideel left". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
model2 = Sequential()
model2.add(InputLayer((7*7*512,)))
model2.add(Dense(units=1024,activation='relu'))
model2.add(Dense(3,activation='softmax'))
model2.summary()
model2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model_perf_relu = model2.fit(train,class_train,epochs=50,validation_data=(test,class_test))
print(model_perf_relu.history.keys())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 1024)              25691136
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 25,694,211
# Trainable params: 25,694,211
# Non-trainable params: 0
# _________________________________________________________________
# Train on 208 samples, validate on 90 samples
# Epoch 1/50
# 208/208 [==============================] - 5s 23ms/step - loss: 1.0811 - acc: 0.5865 - val_loss: 0.6401 - val_acc: 0.7333
# Epoch 2/50
# 208/208 [==============================] - 3s 14ms/step - loss: 0.3224 - acc: 0.8702 - val_loss: 0.5227 - val_acc: 0.7000
# Epoch 3/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.1372 - acc: 0.9615 - val_loss: 0.4454 - val_acc: 0.8333
# Epoch 4/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0677 - acc: 0.9856 - val_loss: 0.3467 - val_acc: 0.8778
# Epoch 5/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0415 - acc: 0.9904 - val_loss: 0.4204 - val_acc: 0.8444
# Epoch 6/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0345 - acc: 0.9856 - val_loss: 0.3446 - val_acc: 0.8556
# Epoch 7/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0209 - acc: 0.9904 - val_loss: 0.3178 - val_acc: 0.8778
# Epoch 8/50
# 208/208 [==============================] - 3s 17ms/step - loss: 0.0149 - acc: 0.9952 - val_loss: 0.4785 - val_acc: 0.8333
# Epoch 9/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0224 - acc: 0.9952 - val_loss: 0.3346 - val_acc: 0.8667
# Epoch 10/50
# 208/208 [==============================] - 3s 14ms/step - loss: 0.0142 - acc: 0.9952 - val_loss: 0.3525 - val_acc: 0.8444
# Epoch 11/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0148 - acc: 0.9952 - val_loss: 0.3629 - val_acc: 0.8444
# Epoch 12/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0122 - acc: 0.9904 - val_loss: 0.3508 - val_acc: 0.8444
# Epoch 13/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0192 - acc: 0.9904 - val_loss: 0.3709 - val_acc: 0.8444
# Epoch 14/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0301 - acc: 0.9952 - val_loss: 0.3188 - val_acc: 0.9000
# Epoch 15/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0252 - acc: 0.9952 - val_loss: 0.4458 - val_acc: 0.8444
# Epoch 16/50
# 208/208 [==============================] - 3s 16ms/step - loss: 0.0138 - acc: 0.9952 - val_loss: 0.3463 - val_acc: 0.8667
# Epoch 17/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0130 - acc: 0.9904 - val_loss: 0.3324 - val_acc: 0.8778
# Epoch 18/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0111 - acc: 0.9952 - val_loss: 0.3550 - val_acc: 0.8444
# Epoch 19/50
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0147 - acc: 0.9952 - val_loss: 0.3650 - val_acc: 0.8444
# Epoch 20/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0095 - acc: 0.9952 - val_loss: 0.3463 - val_acc: 0.8667
# Epoch 21/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0142 - acc: 0.9952 - val_loss: 0.3800 - val_acc: 0.8667
# Epoch 22/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0121 - acc: 0.9952 - val_loss: 0.3629 - val_acc: 0.8556
# Epoch 23/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0127 - acc: 0.9952 - val_loss: 0.3527 - val_acc: 0.8556
# Epoch 24/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0158 - acc: 0.9952 - val_loss: 0.4113 - val_acc: 0.8444
# Epoch 25/50
# 208/208 [==============================] - 4s 19ms/step - loss: 0.0280 - acc: 0.9904 - val_loss: 0.3222 - val_acc: 0.9000
# Epoch 26/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0137 - acc: 0.9952 - val_loss: 0.4972 - val_acc: 0.8333
# Epoch 27/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0320 - acc: 0.9952 - val_loss: 0.4508 - val_acc: 0.8556
# Epoch 28/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0089 - acc: 0.9952 - val_loss: 0.3688 - val_acc: 0.8778
# Epoch 29/50
# 208/208 [==============================] - 5s 25ms/step - loss: 0.0194 - acc: 0.9952 - val_loss: 0.4180 - val_acc: 0.8333
# Epoch 30/50
# 208/208 [==============================] - 5s 25ms/step - loss: 0.0129 - acc: 0.9952 - val_loss: 0.4625 - val_acc: 0.8444
# Epoch 31/50
# 208/208 [==============================] - 5s 24ms/step - loss: 0.0226 - acc: 0.9952 - val_loss: 0.3262 - val_acc: 0.8889
# Epoch 32/50
# 208/208 [==============================] - 5s 22ms/step - loss: 0.0189 - acc: 0.9952 - val_loss: 0.3781 - val_acc: 0.8667
# Epoch 33/50
# 208/208 [==============================] - 5s 23ms/step - loss: 0.0077 - acc: 0.9952 - val_loss: 0.4627 - val_acc: 0.8556
# Epoch 34/50
# 208/208 [==============================] - 5s 23ms/step - loss: 0.0143 - acc: 0.9952 - val_loss: 0.3519 - val_acc: 0.8556
# Epoch 35/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0077 - acc: 0.9952 - val_loss: 0.3714 - val_acc: 0.8556
# Epoch 36/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0078 - acc: 0.9952 - val_loss: 0.3638 - val_acc: 0.8556
# Epoch 37/50
# 208/208 [==============================] - 5s 23ms/step - loss: 0.0076 - acc: 0.9952 - val_loss: 0.3755 - val_acc: 0.8556
# Epoch 38/50
# 208/208 [==============================] - 5s 23ms/step - loss: 0.0084 - acc: 0.9904 - val_loss: 0.4035 - val_acc: 0.8667
# Epoch 39/50
# 208/208 [==============================] - 5s 23ms/step - loss: 0.0130 - acc: 0.9952 - val_loss: 0.3986 - val_acc: 0.8667
# Epoch 40/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0071 - acc: 0.9952 - val_loss: 0.3373 - val_acc: 0.8778
# Epoch 41/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0180 - acc: 0.9952 - val_loss: 0.3592 - val_acc: 0.8667
# Epoch 42/50
# 208/208 [==============================] - 5s 22ms/step - loss: 0.0073 - acc: 0.9904 - val_loss: 0.4580 - val_acc: 0.8556
# Epoch 43/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0179 - acc: 0.9952 - val_loss: 0.4097 - val_acc: 0.8667
# Epoch 44/50
# 208/208 [==============================] - 5s 23ms/step - loss: 0.0198 - acc: 0.9904 - val_loss: 0.3329 - val_acc: 0.8889
# Epoch 45/50
# 208/208 [==============================] - 4s 21ms/step - loss: 0.0115 - acc: 0.9952 - val_loss: 0.3827 - val_acc: 0.8556
# Epoch 46/50
# 208/208 [==============================] - 4s 20ms/step - loss: 0.0167 - acc: 0.9952 - val_loss: 0.4688 - val_acc: 0.8556
# Epoch 47/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0123 - acc: 0.9952 - val_loss: 0.3447 - val_acc: 0.8667
# Epoch 48/50
# 208/208 [==============================] - 4s 18ms/step - loss: 0.0148 - acc: 0.9952 - val_loss: 0.3583 - val_acc: 0.8556
# Epoch 49/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0068 - acc: 0.9952 - val_loss: 0.4310 - val_acc: 0.8556
# Epoch 50/50
# 208/208 [==============================] - 4s 17ms/step - loss: 0.0110 - acc: 0.9952 - val_loss: 0.4162 - val_acc: 0.8667
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.plot(model_perf_relu.history['acc'])
plt.plot(model_perf_relu.history['val_acc'])
plt.title('model accuracy - relu')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
predictions_sig = model.predict_classes(img_test)
predictions_relu = model.predict_classes(img_test)

# %%
print("The screen time of JERRY in test set is (using sigmoid activation)", predictions_sig[predictions==1].shape[0], "seconds")
print("The screen time of TOM in test set is (using sigmoid activation)", predictions_sig[predictions==2].shape[0], "seconds")
# Out:
# The screen time of JERRY in test set is (using sigmoid activation) 18 seconds
# The screen time of TOM in test set is (using sigmoid activation) 44 seconds

# %%
print("The screen time of JERRY in test set is (using relu activation)", predictions_relu[predictions==1].shape[0], "seconds")
print("The screen time of TOM in test set is (using relu activation)", predictions_relu[predictions==2].shape[0], "seconds")
# Out:
# The screen time of JERRY in test set is (using relu activation) 18 seconds
# The screen time of TOM in test set is (using relu activation) 44 seconds
